# %%
# Importing Spark libs.
from pyspark.sql import SparkSession
from pyspark.sql.functions import col, min, max, avg, count
from pyspark.sql.functions import row_number
from pyspark.sql import functions as F
from pyspark.sql import types as T
from pyspark.sql.window import Window
from pyspark.sql.types import ArrayType, StructType, StringType, DoubleType

# Importing Python Data Stat. and vis. libs.
import pandas as pd
import matplotlib.pyplot as plt


# For error handling and utilities 
import json
import requests
import urllib.request
from io import StringIO
from urllib.parse import urlparse
import sys
import os
import tempfile


# TODO: 1 Check warnings - XXX
# TODO: 2 Absadd corupted json handling in to function or make corupted json function - on hold
# TODO: 3 Re-write reading json via Spark as function, double check logic.for controls - DONE
# TODO: 4 Harmonize error messages (numbers and explanation for readme) and code descriptions -
# TODO: 5 Verification of data - DONE
# TODO: 6 Handling of missing values - DONE
# TODO: 7 Transofrmation of OAG DF - DONE
# TODO: 8 Check Load_Data func for absd.json message #2.0.2# not pressent - DONE
# TODO: 9 Add data type in data cleaning functions -
# TODO: 10 Process data and translate date columns check others -
# TODO: 11 KPIs - widow function and Tables -
# TODO: 12 Review of code, Documentation and Bonus topics -

# NOTE: 1 reading more complex file might be necessary to pre-process json

# %%
# Spark builder (check warnings - port 4041)
spark = SparkSession.builder.master("local[*]").appName("AirportFlightDataViz").getOrCreate()
# Out:
# 24/10/13 20:04:06 WARN Utils: Your hostname, codespaces-358acb resolves to a loopback address: 127.0.0.1; using 10.0.12.224 instead (on interface eth0)
# 24/10/13 20:04:06 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 24/10/13 20:04:06 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable

# %%
url_adsb = "https://raw.githubusercontent.com/JM-AE/Airport-Flight-Data/refs/heads/main/adsb.json"
url_adsb_multi = "https://raw.githubusercontent.com/JM-AE/Airport-Flight-Data/refs/heads/main/adsb_multi_aircraft.json"
url_oag = "https://raw.githubusercontent.com/JM-AE/Airport-Flight-Data/refs/heads/main/oag.json"
url_oag_multi = "https://raw.githubusercontent.com/JM-AE/Airport-Flight-Data/refs/heads/main/oag_multiple.json"

# %%
"""
General functions to download data from URL and load it into a Spark DataFrame.
"""

def load_data(url):
    
    # 0 Extract the file name from the URL
    file_name = os.path.basename(urlparse(url).path)
    
    # 1 Download the data
    data = stream_download(url)
    if data is None:
        return None  

    # 2 Analyze the structure (optional if the JSON is large and directly handled by Spark)
    analyze_json_structure(data)
    
    # 3 Try loading into Spark without saving to disk
    try:
        df = load_spark_dataframe_from_memory(data)
        print("#5# DataFrame loaded successfully from memory #5#")
    except Exception as e:
        print(f"#5# Error loading DataFrame from memory: {str(e)} #5#")
        print("#5# Attempting to load DataFrame using file-based approach #5#")

        # Fallback: Save to a temporary file and read into Spark
        tmp_file_path = save_to_temp_file(data, file_name)
        if tmp_file_path is None:
            return None

        # Validate and load the DataFrame from the file
        df = load_spark_dataframe(tmp_file_path)
        if df is None:
            return None  
    
    # 6 Show the DataFrame
    print("#6# DataFrame 1st line #6#")
    df.show(1)
    return df

def stream_download(url):
    """
    #1# Downloads the data from the URL and returns it as a string (JSON) for processing.
    """
    try:
        response = requests.get(url, stream=True)
        if response.status_code == 200:
            print(f"#1# Data from {url} successfully loaded #1#")
            return response.text  # Return the raw JSON data as string
        else:
            print(f"#1# Failed to load {url}. Status code: {response.status_code} #1#")
            return None
    except requests.RequestException as e:
        print(f"#1# Error while downloading data from {url}: {str(e)} #1#")
        return None

def analyze_json_structure(data):
    """
    #2# Analyzes the structure of the JSON data (string) and prints a sample.
    """
    try:
        json_data = json.loads(data)
        if isinstance(json_data, dict):
            keys = list(json_data.keys())
            print(f"#2# Top-level keys found: {keys} #2#")
        elif isinstance(json_data, list):
            print(f"#2# Sample data from the list: {json.dumps(json_data[:1], indent=4)} #2#")
        else:
            print("#2# No valid data structure found. #2#")
    except json.JSONDecodeError:
        print("#2# Failed to parse JSON structure. Skipping analysis. #2#")

def save_to_temp_file(data, file_name):
    """
    #3# Saves the JSON string to a temporary file and returns the file path.
    """
    try:
        tmp_file_path = os.path.join(tempfile.gettempdir(), file_name)
        with open(tmp_file_path, "w") as f:
            f.write(data)
        print(f"#3# Temporary file {file_name} saved #3#")
        return tmp_file_path
    except Exception as e:
        print(f"#3# Error saving temporary file {file_name}: {str(e)} #3#")
        return None

def load_spark_dataframe_from_memory(data):
    """
    Loads the JSON data into a Spark DataFrame from an in-memory string.
    """
    try:
        # Use StringIO to convert string to a file-like object
        json_rdd = spark.sparkContext.parallelize([data])
        df = spark.read.json(json_rdd)
        return df
    except Exception as e:
        print(f"#5# Error loading DataFrame from memory: {str(e)} #5#")
        raise e  # Re-raise the exception for the calling function to handle

def load_spark_dataframe(file_path):
    """
    Loads the JSON data from a file into a Spark DataFrame with error handling.
    """
    try:
        df = spark.read.json(file_path)
        print("#5# DataFrame loaded successfully from file #5#")
        return df
    except Exception as e:
        print(f"#5# Error loading DataFrame from file: {str(e)} #5#")
        print("#5# Attempting to load DataFrame using multiline option #5#")
        
        try:
            df = spark.read.option("multiline", "true").json(file_path)
            print("#5# DataFrame loaded successfully in multiline option #5#")
            return df
        except Exception as e:
            print(f"#5# Error loading DataFrame in multiline option: {str(e)} #5#")
            return None

# %%
df_adsb = load_data(url_adsb)
df_oag = load_data(url_oag)
# Out:
# #1# Data from https://raw.githubusercontent.com/JM-AE/Airport-Flight-Data/refs/heads/main/adsb.json successfully loaded #1#
# #2# Sample data from the list: [
#     {
#         "AircraftId": "400960",
#         "Latitude": 10.81889,
#         "Longitude": 106.65194,
#         "Track": 30,
#         "Altitude": 0,
#         "Speed": 0,
#         "Squawk": 7713,
#         "Type": "A320",
#         "Registration": "G-TTOE",
#         "LastUpdate": 1696278420,
#         "Origin": "SGN",
#         "Destination": "ICN",
#         "Flight": "BA484",
#         "Onground": 1,
#         "Vspeed": 0,
#         "Callsign": "BAW476C",
#         "SourceType": "ADS-B FR24 receivers",
#         "ETA": 0
#     }
# ] #2#
# #5# DataFrame loaded successfully from memory #5#
# #6# DataFrame 1st line #6#
# +----------+--------+--------+-----------+---+------+----------+--------+---------+--------+------+-------+------------+--------------------+-----+------+-----+----+------+
# ...

# %%
"""
Recursively flattens a DF. By explode_outer function.
    
Args: DF, (for oag_df, oag_multi_df)
prefix: Can stay empty or def.by user.
Returns: A flattened DF with  0 nesting.
"""
def flatten_df(df, prefix=""):

    flat_cols = []  # Collects all the non-struct/array columns
    nested_cols = []  # Collects all the struct/array columns for flattening
    
    # Loop through all columns in the DataFrame
    for col_name in df.columns:
        col = df[col_name]
        col_type = df.schema[col_name].dataType
        
        # Check if the column is a struct (nested)
        if isinstance(col_type, T.StructType):
            for field in col_type.fields:
                nested_cols.append(F.col(f"{col_name}.{field.name}").alias(f"{prefix}{col_name}_{field.name}"))
                
        
        # Check if the column is an array, then explode it
        elif isinstance(col_type, T.ArrayType):
            # Explode the array while maintaining the prefix for hierarchical naming
            df = df.withColumn(col_name, F.explode_outer(F.col(col_name)))
            nested_cols.append(F.col(col_name).alias(f"{prefix}{col_name}"))
            
        
        # Otherwise, it's a flat column, add it directly
        else:
            flat_cols.append(F.col(col_name).alias(f"{prefix}{col_name}"))
           
            
    # Select flat columns
    df = df.select(flat_cols + nested_cols)
    
    # If there are nested fields, recurse on the DataFrame
    for nested_col in nested_cols:
        # Check if there are still nested fields in the DataFrame
        nested_fields = [f for f in df.schema.fields if isinstance(f.dataType, (T.StructType, T.ArrayType))]
        if nested_fields:
            # Recursively flatten again if nested fields exist
            df = flatten_df(df, prefix=f"{prefix}")
    
    
    return df

# %%
oag_flat_df = flatten_df(df_oag)
# Out:
# 24/10/13 20:04:21 WARN GarbageCollectionMetrics: To enable non-built-in garbage collector(s) List(G1 Concurrent GC), users should configure it(them) to spark.eventLog.gcMetrics.youngGenerationGarbageCollectors or spark.eventLog.gcMetrics.oldGenerationGarbageCollectors

# %%
def identify_time_columns(df):
    """
    Identifies columns with time-related data: UNIX timestamp columns and time-like (HH:MM:SS) columns.
    
    Args:
    df: The input Spark DataFrame.
    
    Returns:
    A dictionary with two keys: 
    - 'unix_columns' for columns with UNIX timestamps,
    - 'time_format_columns' for columns with time-like formats (HH:MM:SS).
    """
    unix_timestamp_cols = []
    time_format_cols = []
    
    # 1. Identify UNIX timestamp columns (usually numeric fields in seconds since 1970)
    for col, dtype in df.dtypes:
        if dtype in ['long', 'int']:
            # Check if the numeric value falls into the plausible range of UNIX timestamps
            min_max = df.agg(F.min(col).alias("min"), F.max(col).alias("max")).collect()[0]
            min_value, max_value = min_max["min"], min_max["max"]
            
            # UNIX timestamps should be within a certain range, e.g., between 1970 and a plausible future year
            if min_value and max_value and (min_value > 0 and max_value > 1_000_000_000 and max_value < 10_000_000_000):
                unix_timestamp_cols.append(col)
    
    # 2. Identify time format columns (e.g., HH:MM:SS format)
    for col, dtype in df.dtypes:
        if dtype == 'string':
            # Check if the column contains values in the format HH:MM:SS
            sample = df.select(F.regexp_extract(F.col(col), r'^\d{2}:\d{2}(:\d{2})?$', 0).alias("match")) \
                       .filter(F.col("match") != "") \
                       .limit(1)
            if sample.count() > 0:
                time_format_cols.append(col)
    
    print(f"Identified UNIX timestamp columns: {unix_timestamp_cols}")
    print(f"Identified time format columns (e.g., HH:MM:SS): {time_format_cols}")
    
    return {
        'unix_columns': unix_timestamp_cols,
        'time_format_columns': time_format_cols
    }

def convert_unix_time_columns(df, unix_columns):
    """
    Converts columns with UNIX timestamps into a human-readable format (yyyy-MM-dd HH:mm:ss).
    
    Args:
    df: The input Spark DataFrame.
    unix_columns: A list of columns that store UNIX timestamps.
    
    Returns:
    A DataFrame with the UNIX timestamp columns converted to human-readable format.
    """
    for col in unix_columns:
        print(f"Converting column '{col}' from UNIX timestamp to human-readable format.")
        df = df.withColumn(f"{col}_readable", F.from_unixtime(F.col(col), "yyyy-MM-dd HH:mm:ss"))
    return df

def standardize_time_columns(df, time_format_columns):
    """
    Standardizes time format columns to HH:mm:ss format.
    
    Args:
    df: The input Spark DataFrame.
    time_format_columns: A list of columns with time-like formats.
    
    Returns:
    A DataFrame with standardized time format columns.
    """
    for col in time_format_columns:
        print(f"Standardizing time format for column '{col}'.")
        df = df.withColumn(
            f"{col}_standardized",
            F.when(F.length(F.col(col)) == 5, F.concat(F.col(col), F.lit(":00")))
             .otherwise(F.col(col))
        )
    return df

# %%
# Convert LastUpdate to timestamp
up_adsb_df = df_adsb.withColumn("LastUpdateTime", F.from_unixtime(F.col("LastUpdate")))

# %%
"""
General functions for cleaning data in Spark DataFrame.
"""

#def clean_data(df):
#    df = handle_missing_values(df)
#    df = fix_mixed_data_types(df)
#    df = drop_constant_columns(df)
#    return df

def handle_missing_values(df):
    df = df.replace("", None).replace(0, None)
    df = df.na.drop()  # Optional: Drop rows with any null values
    return df

def fix_mixed_data_types(df):
    for col in df.columns:
        if df.select(col).dtypes[0][1] == 'string':
            df = df.withColumn(col, F.when(F.col(col).cast(DoubleType()).isNotNull(), F.col(col).cast(DoubleType())).otherwise(F.col(col)))
    return df

def drop_constant_columns(df):
    for col in df.columns:
        distinct_count = df.select(F.countDistinct(col)).collect()[0][0]
        if distinct_count == 1:
            df = df.drop(col)
            print(f"Column '{col}' has constant values and was dropped.")
    return df

def transform_string_case(df, to_upper=True):
    for col, dtype in df.dtypes:
        if dtype == 'string':
            if to_upper:
                df = df.withColumn(col, F.upper(F.col(col)))
            else:
                df = df.withColumn(col, F.lower(F.col(col)))
    return df

def report_data_issues(df):
    print("# Data Issues Report #")
    
    for col in df.columns:
        mixed_type_count = df.select(col).filter(F.col(col).cast(DoubleType()).isNotNull()).count()
        if mixed_type_count > 0:
            print(f" - {col} contains mixed strings and numbers.")
    
    for col in df.columns:
        null_count = df.filter(F.col(col).isNull()).count()
        if null_count > 0:
            print(f" - {col} has {null_count} null values.")
    
    for col in df.columns:
        distinct_count = df.select(F.countDistinct(col)).collect()[0][0]
        if distinct_count == 1:
            print(f" - {col} contains only one unique value.")

def identify_column_data_types(df):
    print("# Identified Data Types for Columns #")
    column_types = {}
    for col, dtype in df.dtypes:
        print(f"Column '{col}' has data type: {dtype}")
        column_types[col] = dtype
    return column_types

def identify_mixed_data_patterns(df):
    print("# Detecting Mixed Data Patterns in Columns #")
    mixed_columns = {}
    for col in df.columns:
        print(f"Analyzing column '{col}' for mixed data patterns...")
        df = df.withColumn(f"{col}_type", 
                           F.when(F.col(col).cast(DoubleType()).isNotNull(), "number")
                           .when(F.col(col).cast(IntegerType()).isNotNull(), "integer")
                           .when(F.col(col).cast(StringType()).isNotNull(), "string")
                           .otherwise("unknown"))
        
        distinct_types = df.select(f"{col}_type").distinct().rdd.flatMap(lambda x: x).collect()
        
        if len(distinct_types) > 1:
            print(f"Column '{col}' has mixed data types: {distinct_types}")
            mixed_columns[col] = distinct_types
        else:
            print(f"Column '{col}' has consistent data type: {distinct_types[0]}")
        
        df = df.drop(f"{col}_type")
    
    return mixed_columns

# %%
"""
ASSIGMENT 6: Display results in form of table.

Display a DataFrame as a styled table using matplotlib.
Args: pandas DataFrame
"""

def display_table(df):

    
    fig, ax = plt.subplots(figsize=(8, 4))
    ax.axis('tight')
    ax.axis('off')

    # Create a table
    table = ax.table(cellText=df.values,
                     colLabels=df.columns,
                     cellLoc='center',
                     loc='center',
                     colColours=["#f5f5f5"] * len(df.columns))

    # Style the table
    table.auto_set_font_size(True)

    for (i, j), cell in table.get_celld().items():
        if i == 0:  # Header
            cell.set_text_props(weight='bold', color='white')
            cell.set_facecolor('#494391')  # Header color
        else:
            # Use a single condition for alternating row colors
            cell.set_facecolor('#d9d9d9' if i % 2 else '#ffffff')

    plt.show()

# %%
"""
ASSIGMENT 3a: Basic KPI Airport average speed according airport of ORIGIN.
NOTE 3a.1: according adsd.json 
NOTE 3a.2: static nature of data is giving same results betwen Origina and Destination airport.
"""
def avg_speed_origin(df):
    avg_speed_per_airport_origin = df.groupBy("Origin").agg(F.avg("Speed").alias("AverageSpeed"))
    return avg_speed_per_airport_origin

# %%
display_table(avg_speed_origin(df_adsb).toPandas())

# %%
"""
ASSIGMENT 3a: Basic KPI Airport average speed according DESTINATION airport.
see NOTE 3a.1, NOTE 3a.2
"""
def avg_speed_dest(df):
    avg_speed_per_airport_dest = df_adsb.groupBy("Destination").agg(F.avg("Speed").alias("AverageSpeed"))

    return avg_speed_per_airport_dest

# %%
display_table(avg_speed_dest(df_adsb).toPandas())

# %%
"""
ASSIGMENT 3a: Basic KPI average speed according TYPE of aircraft.
"""
def avg_speed_type(df):
    avg_speed_per_aircraft = df.groupBy("Type").agg(F.round(F.avg("Speed"), 1).alias("AverageSpeed"))   
    
    return avg_speed_per_aircraft

# %%
display_table(avg_speed_type(df_adsb).toPandas())

# %%
"""
ASSIGMENT 3b: Basic KPIs Total NUMBER of delayed flights DEPARTURES per Airport.
Counts the number of delayed arrivals. Count is based on *departure_actualTime_outGateTimeliness column.  
Args: oag_flat_df/oag_milti_flat_df (flattened DF).  
Returns: DF - count of delayed departures per airport.
"""

def amount_delayed_departures(df):
    delayed_departures_amo = oag_flat_df.filter(
        F.col("data_statusDetails_departure_actualTime_outGateTimeliness") == "Delayed").groupBy("data_statusDetails_departure_airport_iata") \
        .agg(F.count("*").alias("number_of_delayed_departures"))
    
    return delayed_departures_amo

# %%
display_table(amount_delayed_departures(oag_flat_df).toPandas())

# %%
"""
ASSIGMENT 3b: Basic KPIs Total NUMBER of delayed flights ARRIVALS per Airport.

Counts the number of delayed arrivals. Count is based on *arrival_actualTime_inGateTimeliness column.  
Args: oag_flat_df/oag_milti_flat_df (flattened DF).  
Returns: DF - count of delayed arrivals per airport.
"""

def amount_delayed_arrivals(df):
    delayed_arrivals_amo = oag_flat_df.filter(
        F.col("data_statusDetails_arrival_actualTime_inGateTimeliness") == "Delayed").groupBy("data_statusDetails_arrival_airport_iata") \
        .agg(F.count("*").alias("number_of_delayed_arrivals"))
    
    return delayed_arrivals_amo

# %%
display_table(amount_delayed_arrivals(oag_flat_df).toPandas())

# %%
"""
ASSIGMENT 3b: Basic KPIs Total TIME of delayed flights DEPARTURES per Airport.

Calculates the total minutes of delay for departures. (HH:MM:SS format to minutes)
Args: oag_flat_df/oag_milti_flat_df (flattened DF).
Returns: DF - total delay in minutes for arrivals per airport.
"""
def total_departure_delay_minutes(df):
    
    departure_delay = df.filter(F.col("data_statusDetails_departure_actualTime_outGateVariation").isNotNull()) \
        .withColumn("departure_delay_minutes", 
                    F.split(F.col("data_statusDetails_departure_actualTime_outGateVariation"), ":")[0].cast("int") * 60 +
                    F.split(F.col("data_statusDetails_departure_actualTime_outGateVariation"), ":")[1].cast("int")) \
        .groupBy("data_statusDetails_departure_airport_iata") \
        .agg(F.sum("departure_delay_minutes").alias("total_departure_delay_minutes"))
    
    return departure_delay

# %%
display_table(total_departure_delay_minutes(oag_flat_df).toPandas())

# %%
"""
ASSIGMENT 3b: Basic KPIs Total TIME of delayed flights ARRIVALS per Airport.

Calculates the total minutes of delay for arrivals. (HH:MM:SS format to minutes)
Args: oag_flat_df/oag_milti_flat_df (flattened DF).
Returns: DF - total delay in minutes for arrivals per airport.
 
"""
def total_arrival_delay_minutes(df):
    
 
    arrival_delay = df.filter(F.col("data_statusDetails_arrival_actualTime_inGateVariation").isNotNull()) \
        .withColumn("arrival_delay_minutes", 
                    F.split(F.col("data_statusDetails_arrival_actualTime_inGateVariation"), ":")[0].cast("int") * 60 +
                    F.split(F.col("data_statusDetails_arrival_actualTime_inGateVariation"), ":")[1].cast("int")) \
        .groupBy("data_statusDetails_arrival_airport_iata") \
        .agg(F.sum("arrival_delay_minutes").alias("total_arrival_delay_minutes"))

    return arrival_delay

# %%
display_table(total_arrival_delay_minutes(oag_flat_df).toPandas())

# %%
"""
ASSIGMENT 4a: 


 
"""
def window_part(df):
    
    # Window spec.
    window_spec_4a = Window.partitionBy("Flight").orderBy(F.desc("LastUpdateTime"))

    # Apply the window partitioning 
    windowed_df = df.select(
    F.col("Flight").alias("FlightID"),
    F.first("LastUpdateTime").over(window_spec_4a).alias("LatestUpdate"))

    return windowed_df

# %%
display_table(window_part(up_adsb_df).toPandas())

# %%
def get_latest_update_time():
    # Window specification for latest update
    window_latest = Window.partitionBy("Flight")
    
    return windowed_df.withColumn(
        "LatestUpdateTime",
        F.max("LastUpdateTime").over(window_latest)
    ).select("Flight", "LatestUpdateTime").distinct()

def get_soonest_update_time():
    # Window specification for soonest update
    window_soonest = Window.partitionBy("Flight")
    
    return windowed_df.withColumn(
        "SoonestUpdateTime",
        F.min("LastUpdateTime").over(window_soonest)
    ).select("Flight", "SoonestUpdateTime").distinct()

# Get latest update time for each flight
latest_updates = get_latest_update_time()
print("Latest Updates:")
latest_updates.show()

# Get soonest update time for each flight
soonest_updates = get_soonest_update_time()
print("Soonest Updates:")
soonest_updates.show()

# If you need both in a single DataFrame:
window_spec = Window.partitionBy("Flight")
combined_updates = windowed_df.withColumn(
    "LatestUpdateTime",
    F.max("LastUpdateTime").over(window_spec)
).withColumn(
    "SoonestUpdateTime",
    F.min("LastUpdateTime").over(window_spec)
).select("Flight", "LatestUpdateTime", "SoonestUpdateTime").distinct()

print("Combined Updates:")
combined_updates.show()
# Out:
# Latest Updates:
# +------+-------------------+
# |Flight|   LatestUpdateTime|
# +------+-------------------+
# |AAL476|2023-10-03 16:36:00|
# | BA484|2023-10-02 23:47:00|
# |LXJ476|2023-10-03 16:25:20|
# | QR476|2023-10-02 23:12:15|
# +------+-------------------+
#
# Soonest Updates:
# +------+-------------------+
# |Flight|  SoonestUpdateTime|
# +------+-------------------+
# |AAL476|2023-10-03 16:36:00|
# | BA484|2023-10-02 23:47:00|
# |LXJ476|2023-10-03 16:25:20|
# | QR476|2023-10-02 23:12:15|
# +------+-------------------+
#
# Combined Updates:
# +------+-------------------+-------------------+
# |Flight|   LatestUpdateTime|  SoonestUpdateTime|
# +------+-------------------+-------------------+
# |AAL476|2023-10-03 16:36:00|2023-10-03 16:36:00|
# | BA484|2023-10-02 23:47:00|2023-10-02 23:47:00|
# |LXJ476|2023-10-03 16:25:20|2023-10-03 16:25:20|
# | QR476|2023-10-02 23:12:15|2023-10-02 23:12:15|
# +------+-------------------+-------------------+
